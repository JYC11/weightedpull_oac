# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data = pd.read_excel("cleaned_data_no_dummies.xlsx")

# %%
dummy = pd.read_excel("cleand_data_with_dummies.xlsx")

# %%
dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1127 entries, 0 to 1126
# Data columns (total 37 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   height                                   1127 non-null   float64
#  1   weight                                   1127 non-null   float64
#  2   upper_arm_length                         462 non-null    object
#  3   weight_x_repmax                          1127 non-null   object
#  4   orm                                      987 non-null    float64
#  5   max_pulls                                998 non-null    float64
#  6   specific_training_time                   1117 non-null   object
#  7   sessions_per_week                        860 non-null    float64
#  8   years_of_training                        870 non-null    float64
#  9   pull_style_both                          178 non-null    float64
#  10  pull_style_none                          167 non-null    float64
#  11  pull_style_npu                           2 non-null      float64
#  12  pull_style_rpu                           4 non-null      float64
#  13  pull_style_wcu                           163 non-null    float64
#  14  pull_style_wpu                           613 non-null    float64
#  15  oac_ability_both                         162 non-null    float64
#  16  oac_ability_multiple-both                1 non-null      float64
#  17  oac_ability_multiple-negatives/bad-form  198 non-null    float64
#  18  oac_ability_multiple-oac                 1 non-null      float64
#  19  oac_ability_multiple-oap                 5 non-null      float64
#  20  oac_ability_neither                      272 non-null    float64
#  21  oac_ability_never-tried                  55 non-null     float64
#  22  oac_ability_oac                          75 non-null     float64
#  23  oac_ability_oap                          96 non-null     float64
#  24  oac_ability_one-negative                 262 non-null    float64
#  25  best_oac_contribution_band               323 non-null    float64
#  26  best_oac_contribution_climbers-approach  146 non-null    float64
#  27  best_oac_contribution_climbing           25 non-null     float64
#  28  best_oac_contribution_eccentrics         511 non-null    float64
#  29  best_oac_contribution_grip               5 non-null      float64
#  30  best_oac_contribution_high-volume        6 non-null      float64
#  31  best_oac_contribution_isometrics         17 non-null     float64
#  32  best_oac_contribution_mixed-grip/mantle  187 non-null    float64
#  33  best_oac_contribution_partials           95 non-null     float64
#  34  best_oac_contribution_pulley             146 non-null    float64
#  35  best_oac_contribution_rope-climbs        43 non-null     float64
#  36  best_oac_contribution_weighted-pulls     546 non-null    float64
# dtypes: float64(34), object(3)
# memory usage: 325.9+ KB

# %%
copy = data.copy()
copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1127 entries, 0 to 1126
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   height                    1127 non-null   float64
#  1   weight                    1127 non-null   float64
#  2   upper_arm_length          462 non-null    object
#  3   pull_style                1127 non-null   object
#  4   weight_x_repmax           1127 non-null   object
#  5   orm                       987 non-null    float64
#  6   max_pulls                 998 non-null    float64
#  7   oac_ability               1127 non-null   object
#  8   best_contribution_to_oac  946 non-null    object
#  9   specific_training_time    1117 non-null   object
#  10  sessions_per_week         860 non-null    float64
#  11  years_of_training         870 non-null    float64
# dtypes: float64(6), object(6)
# memory usage: 105.8+ KB

# %%
copy.describe()
# Out:
#             height       weight         orm   max_pulls  sessions_per_week  \
# count  1127.000000  1127.000000  987.000000  998.000000         860.000000
# mean    176.029839    71.358354   47.923036   21.065130           1.952035
# std       8.204170     9.049552   18.740911    6.618624           0.997572
# min     153.000000    38.555320    1.000000   10.000000           0.250000
# 25%     172.000000    65.000000   35.992483   16.000000           1.000000
# 50%     176.000000    71.000000   45.833333   20.000000           2.000000
# 75%     182.000000    77.110640   57.833333   25.000000           2.000000
# max     197.000000   106.594120  156.200000   50.000000           7.000000
#
#        years_of_training
# count         870.000000
# mean            1.702879
# std             1.621270
# min             0.025000
# 25%             1.000000
# 50%             1.000000
# 75%             2.000000
# max            17.000000

# %%
copy["height"].hist()
# Out:
# <AxesSubplot:>

# %%
copy["weight"].hist()
# Out:
# <AxesSubplot:>

# %%
#besides some really elite pullers and people who don't know their orm, the distibution seems pretty normal
copy["orm"].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
copy["pull_style"].value_counts()
# Out:
# wpu     613
# both    178
# none    167
# wcu     163
# rpu       4
# npu       2
# Name: pull_style, dtype: int64

# %%
copy["pull_style"].value_counts().plot.bar()
plt.title("Frequency of each weighted pulling style")
plt.xlabel("Pull style")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### wpu = weighted pull up
# ### wcu = weighted chin up
# ### both = both
# ### npu = neutral grip pull up
# ### rpu = ring pull up
# ### none = does not do weighted pull ups

# %%
copy["oac_ability"].value_counts()
# Out:
# neither                        272
# one-negative                   262
# multiple-negatives/bad-form    198
# both                           162
# oap                             96
# oac                             75
# never-tried                     55
# multiple-oap                     5
# multiple-both                    1
# multiple-oac                     1
# Name: oac_ability, dtype: int64

# %%
copy["oac_ability"].value_counts().plot.bar()

plt.title("OAC/OAP ability and frequency")
plt.ylabel("Frequency")
plt.xlabel("OAC/OAP ability")
# Out:
# Text(0.5, 0, 'OAC/OAP ability')

# %% [markdown]
# ### oac = one arm chin up
# ### oap = one arm pull up

# %%
def get_percentage(x):
    bw = x["weight"]
    orm = x["orm"]
    return orm/bw*100

# %% [markdown]
# ### now will get orm as % of bodyweight, shortened to orm_as_%

# %%
copy["orm_as_%"] = copy.apply(get_percentage,axis=1)
copy.head()
# Out:
#    height  weight upper_arm_length pull_style weight_x_repmax   orm  \
# 0   180.0    84.0               38        wpu            51x1  51.0
# 1   192.0    78.0              NaN       none             0x0   NaN
# 2   168.0    55.0              NaN        wpu            75x1  75.0
# 3   190.0    80.0               14        wpu            25x1  25.0
# 4   172.0    68.0              NaN        wcu            40x2  47.2
#
#    max_pulls                  oac_ability           best_contribution_to_oac  \
# 0        NaN                 one-negative        pulley,high-volume,partials
# 1       12.0                      neither                                NaN
# 2       18.0  multiple-negatives/bad-form  climbers-approach,eccentrics,band
# 3       10.0                      neither                     weighted-pulls
# 4       18.0                      neither                                NaN
#
#   specific_training_time  sessions_per_week  years_of_training    orm_as_%
# 0                    2/2                2.0                2.0   60.714286
# 1                    0/0                NaN                NaN         NaN
# 2                    2/1                2.0                1.0  136.363636
# 3                    2/1                2.0                1.0   31.250000
# 4                    1/0                1.0                NaN   69.411765

# %%
cols = list(copy.columns)
popped = cols.pop()
cols.insert(6,popped)
copy = copy[cols]
copy.head()
# Out:
#    height  weight upper_arm_length pull_style weight_x_repmax   orm  \
# 0   180.0    84.0               38        wpu            51x1  51.0
# 1   192.0    78.0              NaN       none             0x0   NaN
# 2   168.0    55.0              NaN        wpu            75x1  75.0
# 3   190.0    80.0               14        wpu            25x1  25.0
# 4   172.0    68.0              NaN        wcu            40x2  47.2
#
#      orm_as_%  max_pulls                  oac_ability  \
# 0   60.714286        NaN                 one-negative
# 1         NaN       12.0                      neither
# 2  136.363636       18.0  multiple-negatives/bad-form
# 3   31.250000       10.0                      neither
# 4   69.411765       18.0                      neither
#
#             best_contribution_to_oac specific_training_time  \
# 0        pulley,high-volume,partials                    2/2
# 1                                NaN                    0/0
# 2  climbers-approach,eccentrics,band                    2/1
# 3                     weighted-pulls                    2/1
# 4                                NaN                    1/0
#
#    sessions_per_week  years_of_training
# 0                2.0                2.0
# 1                NaN                NaN
# 2                2.0                1.0
# 3                2.0                1.0
# 4                1.0                NaN

# %%
copy["orm_as_%"].hist(bins=30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### looks like we have some people over reporting their weighted pull numbers or our formula is too optimistic
# ### hmmm what to do...

# %%
over_200 = copy[copy["orm_as_%"]>=150]
over_200
# Out:
#       height    weight upper_arm_length pull_style weight_x_repmax  \
# 25    175.00  70.00000              NaN        wpu           115x2
# 139   179.00  78.00000              NaN        wcu           120x1
# 173   183.00  74.00000              NaN        wpu           125x1
# 182   178.00  72.00000               39        wpu           119x1
# 224   183.00  76.00000              NaN       none           76x13
# 234   165.00  58.00000               30       both            90x1
# 253   179.00  79.00000              NaN        wpu           120x1
# 388   189.00  86.00000              NaN       both            95x7
# 394   185.00  85.00000               37        wcu           130x1
# 532   183.00  83.00000               40       both           120x2
# 723   180.00  80.00000              NaN        wpu           120x3
# 737   184.00  85.00000             37.5        wpu           116x6
# 836   163.00  63.00000              NaN       both            75x5
# 1114  182.88  83.91452              NaN        wcu     83.91452x12
#
#              orm    orm_as_%  max_pulls                  oac_ability  \
# 25    127.333333  181.904762       20.0                 one-negative
# 139   120.000000  153.846154       17.0                 one-negative
# 173   125.000000  168.918919       25.0  multiple-negatives/bad-form
# 182   119.000000  165.277778       24.0  multiple-negatives/bad-form
# 224   141.866667  186.666667       13.0  multiple-negatives/bad-form
# 234    90.000000  155.172414       25.0  multiple-negatives/bad-form
# 253   120.000000  151.898734       20.0                      neither
# 388   137.233333  159.573643        NaN                      neither
# 394   130.000000  152.941176       15.0                 one-negative
# 532   133.533333  160.883534       19.0  multiple-negatives/bad-form
# 723   140.000000  175.000000       22.0                      neither
# 737   156.200000  183.764706       16.0                          oap
# 836    98.000000  155.555556        NaN  multiple-negatives/bad-form
# 1114  151.046136  180.000000       30.0                 one-negative
#
#                                best_contribution_to_oac  \
# 25                                                  NaN
# 139                                      weighted-pulls
# 173                           eccentrics,weighted-pulls
# 182                           isometrics,weighted-pulls
# 224                        climbers-approach,eccentrics
# 234                                      weighted-pulls
# 253                                              pulley
# 388   climbers-approach,eccentrics,mixed-grip/mantle...
# 394             pulley,mixed-grip/mantle,weighted-pulls
# 532                  eccentrics,partials,weighted-pulls
# 723                      eccentrics,band,weighted-pulls
# 737   eccentrics,mixed-grip/mantle,rope-climbs,weigh...
# 836                    mixed-grip/mantle,weighted-pulls
# 1114                                  climbers-approach
#
#      specific_training_time  sessions_per_week  years_of_training
# 25                      0/0                NaN                NaN
# 139                     1/1                1.0                1.0
# 173                     3/2                3.0                2.0
# 182                     1/1                1.0                1.0
# 224                     3/2                3.0                2.0
# 234                     1/1                1.0                1.0
# 253                     2/1                2.0                1.0
# 388                     1/1                1.0                1.0
# 394                     1/7                1.0                7.0
# 532                     3/3                3.0                3.0
# 723                   0.5/3                0.5                3.0
# 737                     1/4                1.0                4.0
# 836                     3/3                3.0                3.0
# 1114                    2/1                2.0                1.0

# %%
copy.to_excel("no_dummies_v2.xlsx",index=False)

# %%
dummy["orm_as_%"] = dummy.apply(get_percentage,axis=1)
cols = list(dummy.columns)
popped = cols.pop()
cols.insert(5,popped)
dummy = dummy[cols]
dummy.head()
# Out:
#    height  weight upper_arm_length weight_x_repmax   orm    orm_as_%  \
# 0   180.0    84.0               38            51x1  51.0   60.714286
# 1   192.0    78.0              NaN             0x0   NaN         NaN
# 2   168.0    55.0              NaN            75x1  75.0  136.363636
# 3   190.0    80.0               14            25x1  25.0   31.250000
# 4   172.0    68.0              NaN            40x2  47.2   69.411765
#
#    max_pulls specific_training_time  sessions_per_week  years_of_training  \
# 0        NaN                    2/2                2.0                2.0
# 1       12.0                    0/0                NaN                NaN
# 2       18.0                    2/1                2.0                1.0
# 3       10.0                    2/1                2.0                1.0
# 4       18.0                    1/0                1.0                NaN
#
#    ...  best_oac_contribution_climbing  best_oac_contribution_eccentrics  \
# 0  ...                             NaN                               NaN
# 1  ...                             NaN                               NaN
# 2  ...                             NaN                               1.0
# 3  ...                             NaN                               NaN
# 4  ...                             NaN                               NaN
#
#    best_oac_contribution_grip  best_oac_contribution_high-volume  \
# 0                         NaN                                1.0
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                         NaN                                NaN
# 4                         NaN                                NaN
#
#    best_oac_contribution_isometrics  best_oac_contribution_mixed-grip/mantle  \
# 0                               NaN                                      NaN
# 1                               NaN                                      NaN
# 2                               NaN                                      NaN
# 3                               NaN                                      NaN
# 4                               NaN                                      NaN
#
#    best_oac_contribution_partials  best_oac_contribution_pulley  \
# 0                             1.0                           1.0
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
#
#    best_oac_contribution_rope-climbs  best_oac_contribution_weighted-pulls
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
# 2                                NaN                                   NaN
# 3                                NaN                                   1.0
# 4                                NaN                                   NaN
#
# [5 rows x 38 columns]

# %%
dummy.to_excel("dummies_v2.xlsx",index=False)

# %%
def orm_binning(x):
    prcnt  = x["orm_as_%"]
    if prcnt >= 180:
        return ">=180%"
    elif prcnt >= 160:
        return "160~179%"
    elif prcnt >=140:
        return "140~159%"
    elif prcnt >=120:
        return "120~139%"
    elif prcnt >=100:
        return "100~119%"
    elif prcnt >=80:
        return "80~99%"
    elif prcnt >=60:
        return "60~79%"
    elif prcnt >=40:
        return "40~59%"
    elif prcnt >=20:
        return "20~39%"
    elif prcnt >=0:
        return "0~19%"
    else:
        return None

# %%
copy["orm_bins"] = copy.apply(orm_binning,axis=1)
copy.head()
# Out:
#    height  weight upper_arm_length pull_style weight_x_repmax   orm  \
# 0   180.0    84.0               38        wpu            51x1  51.0
# 1   192.0    78.0              NaN       none             0x0   NaN
# 2   168.0    55.0              NaN        wpu            75x1  75.0
# 3   190.0    80.0               14        wpu            25x1  25.0
# 4   172.0    68.0              NaN        wcu            40x2  47.2
#
#      orm_as_%  max_pulls                  oac_ability  \
# 0   60.714286        NaN                 one-negative
# 1         NaN       12.0                      neither
# 2  136.363636       18.0  multiple-negatives/bad-form
# 3   31.250000       10.0                      neither
# 4   69.411765       18.0                      neither
#
#             best_contribution_to_oac specific_training_time  \
# 0        pulley,high-volume,partials                    2/2
# 1                                NaN                    0/0
# 2  climbers-approach,eccentrics,band                    2/1
# 3                     weighted-pulls                    2/1
# 4                                NaN                    1/0
#
#    sessions_per_week  years_of_training  orm_bins
# 0                2.0                2.0    60~79%
# 1                NaN                NaN      None
# 2                2.0                1.0  120~139%
# 3                2.0                1.0    20~39%
# 4                1.0                NaN    60~79%

# %%
cols = list(copy.columns)
popped = cols.pop()
cols.insert(7,popped)
cols
# Out:
# ['height',
#  'weight',
#  'upper_arm_length',
#  'pull_style',
#  'weight_x_repmax',
#  'orm',
#  'orm_as_%',
#  'orm_bins',
#  'max_pulls',
#  'oac_ability',
#  'best_contribution_to_oac',
#  'specific_training_time',
#  'sessions_per_week',
#  'years_of_training']

# %%
copy = copy[cols]
copy.head()
# Out:
#    height  weight upper_arm_length pull_style weight_x_repmax   orm  \
# 0   180.0    84.0               38        wpu            51x1  51.0
# 1   192.0    78.0              NaN       none             0x0   NaN
# 2   168.0    55.0              NaN        wpu            75x1  75.0
# 3   190.0    80.0               14        wpu            25x1  25.0
# 4   172.0    68.0              NaN        wcu            40x2  47.2
#
#      orm_as_%  orm_bins  max_pulls                  oac_ability  \
# 0   60.714286    60~79%        NaN                 one-negative
# 1         NaN      None       12.0                      neither
# 2  136.363636  120~139%       18.0  multiple-negatives/bad-form
# 3   31.250000    20~39%       10.0                      neither
# 4   69.411765    60~79%       18.0                      neither
#
#             best_contribution_to_oac specific_training_time  \
# 0        pulley,high-volume,partials                    2/2
# 1                                NaN                    0/0
# 2  climbers-approach,eccentrics,band                    2/1
# 3                     weighted-pulls                    2/1
# 4                                NaN                    1/0
#
#    sessions_per_week  years_of_training
# 0                2.0                2.0
# 1                NaN                NaN
# 2                2.0                1.0
# 3                2.0                1.0
# 4                1.0                NaN

# %%
groupby_oac = copy.groupby("oac_ability").mean()
groupby_oac = groupby_oac.iloc[[1,0,3,4,7,8,2,9,5,6]]
groupby_oac
# Out:
#                                  height     weight        orm    orm_as_%  \
# oac_ability
# multiple-both                168.000000  67.000000  68.466667  102.189055
# both                         173.272778  69.264733  60.430157   86.368664
# multiple-oac                 172.000000  72.000000  70.000000   97.222222
# multiple-oap                 170.732000  68.469112  56.599859   83.738820
# oac                          174.844800  70.976992  52.805510   74.521552
# oap                          174.500208  68.847890  53.249483   76.391014
# multiple-negatives/bad-form  175.863535  71.288316  50.974419   70.739238
# one-negative                 177.123969  72.474229  44.712113   60.901473
# neither                      177.788011  73.097262  39.109166   53.357643
# never-tried                  175.829091  69.094016  37.337062   52.768069
#
#                              max_pulls  sessions_per_week  years_of_training
# oac_ability
# multiple-both                34.000000           3.000000           5.000000
# both                         27.979310           2.068015           2.466763
# multiple-oac                 33.000000           2.000000           0.300000
# multiple-oap                 30.000000           2.100000           1.400000
# oac                          22.625000           1.949275           2.465634
# oap                          25.129412           2.080000           2.115062
# multiple-negatives/bad-form  21.254237           2.045455           1.411450
# one-negative                 19.700855           1.713270           1.366232
# neither                      16.819672           1.948276           1.309195
# never-tried                  17.022727           2.326087           1.400000

# %%
oac_pivot = copy.pivot_table(index="oac_ability",columns="orm_bins",aggfunc="size",fill_value=0)
oac_pivot = oac_pivot[["0~19%","20~39%","40~59%","60~79%","80~99%","100~119%","120~139%","140~159%","160~179%",">=180%"]]
oac_pivot = oac_pivot.iloc[[1,0,3,4,7,8,2,9,5,6]]
oac_pivot
# Out:
# orm_bins                     0~19%  20~39%  40~59%  60~79%  80~99%  100~119%  \
# oac_ability
# multiple-both                    0       0       0       0       0         1
# both                             0       0       5      41      69        28
# multiple-oac                     0       0       0       0       1         0
# multiple-oap                     0       0       1       1       2         1
# oac                              1       1      11      30      23         2
# oap                              0       1      14      36      31         1
# multiple-negatives/bad-form      1      10      40      87      21         5
# one-negative                     2      18      98      92      14         4
# neither                          6      50     119      50       2         0
# never-tried                      1      12      14       7       2         1
#
# orm_bins                     120~139%  140~159%  160~179%  >=180%
# oac_ability
# multiple-both                       0         0         0       0
# both                                2         0         0       0
# multiple-oac                        0         0         0       0
# multiple-oap                        0         0         0       0
# oac                                 2         0         0       0
# oap                                 2         0         0       1
# multiple-negatives/bad-form         2         3         3       1
# one-negative                        0         2         0       2
# neither                             4         4         1       0
# never-tried                         0         1         0       0
